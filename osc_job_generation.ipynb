# %%
import os
import pandas as pd
from pathlib import Path
import shutil
from shutil import rmtree

# %%
def delete_file_or_dir(pth: str) -> None:
    """
    Deletes a file or directory
    
    Arguments:
    -----------
    - path: A file or directory path. It could either be relative or absolute.
    """
    pth = Path(pth)
    for child in pth.glob('*'):
        if child.is_file():
            child.unlink()
        else:
            rmtree(child)
    pth.rmdir()   
                

def create_dir(pth: str):
    """
    Create a directory
    
    Arguments:
    -----------
    - path: A directory path. It could either be relative or absolute.
    """
    try:
        Path(pth).mkdir(parents=True, exist_ok=True)
    except OSError as e:
        raise e

# %%
# !mkdir -p output/BOWTIE
# !mkdir -p output/TELESCOPE

# %%
manifests_dpath: str = "manifests"
jobs_s1_dpath: str = "jobs_step1"
jobs_s2_dpath: str = "jobs_step2"

# %%
if os.path.isdir(manifests_dpath):
    delete_file_or_dir(manifests_dpath)
create_dir(manifests_dpath)

if os.path.isdir(jobs_s1_dpath):
    delete_file_or_dir(jobs_s1_dpath)
create_dir(jobs_s1_dpath)

if os.path.isdir(jobs_s2_dpath):
    delete_file_or_dir(jobs_s2_dpath)
create_dir(jobs_s2_dpath)

# %%
# read data files (fastq files)
rawdata_path = "/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq"

# %%
def read_fastq_files(rawdata_path: str) -> list:
    """
    Read FASTQ files from the specified path and return unique sample identifiers.

    Supported filename patterns:
      - <sample>_R1.fastq.gz / <sample>_R2.fastq.gz
      - <sample>_1.fastq.gz  / <sample>_2.fastq.gz

    Arguments:
    ----------
    rawdata_path : str
        Path to directory containing FASTQ files

    Returns:
    --------
    list
        Sorted list of unique sample identifiers
    """
    import os
    import glob
    import re

    pattern = os.path.join(rawdata_path, "*.fastq.gz")
    fastq_files = glob.glob(pattern)

    sample_ids = set()

    # Regex: strip _R1/_R2 or _1/_2 before .fastq.gz
    regex = re.compile(r"(.+?)(?:_R?[12])\.fastq\.gz$")

    for file_path in fastq_files:
        filename = os.path.basename(file_path)
        match = regex.match(filename)
        if match:
            sample_ids.add(match.group(1))

    return sorted(sample_ids)

# %%
# Test the function
sample_ids = read_fastq_files(rawdata_path)
print(f"Found {len(sample_ids)} unique samples:")
for sample_id in sample_ids:
    print(f"  {sample_id}")
# Out:
# Found 1709 unique samples:
#   AZSFJ00239-RNA
#   AZSFJ00240-RNA
#   AZSFJ00241-RNA
#   AZSFJ00242-RNA
#   AZSFJ00243-RNA
#   AZSFJ00244-RNA
#   AZSFJ00245-RNA
#   AZSFJ00246-RNA
#   AZSFJ00247-RNA
#   AZSFJ00248-RNA
#   AZSFJ00249-RNA
#   AZSFJ00250-RNA
#   AZSFJ00251-RNA
#   AZSFJ00252-RNA
#   AZSFJ00253-RNA
#   AZSFJ00254-RNA
#   AZSFJ00255-RNA
#   AZSFJ00256-RNA
#   AZSFJ00257-RNA
#   AZSFJ00258-RNA
#   AZSFJ00259-RNA
#   AZSFJ00260-RNA
#   AZSFJ00261-RNA
#   AZSFJ00262-RNA
#   AZSFJ00263-RNA
#   AZSFJ00265-RNA
#   AZSFL01913-RNA
#   AZSFL01914-RNA
#   AZSFL01915-RNA
#   AZSFL01917-RNA
#   FT-SA202513R
#   FT-SA202514R
#   FT-SA202515R
#   FT-SA202516R
#   FT-SA202517R
#   FT-SA202518R
#   FT-SA202519R
#   FT-SA202520R
#   FT-SA202521R
#   FT-SA202522R
#   FT-SA202523R
#   FT-SA202524R
#   FT-SA202525R
#   FT-SA202526R
#   FT-SA202527R
#   FT-SA202528R
#   FT-SA202529R
#   FT-SA202530R
#   FT-SA202531R
#   FT-SA202532R
#   FT-SA202534R
#   FT-SA202535R
#   FT-SA202536R
#   FT-SA202537R
#   FT-SA202538R
#   FT-SA202539R
#   FT-SA205562R
#   FT-SA205563R
#   FT-SA205564R
#   FT-SA205565R
#   FT-SA205566R
#   FT-SA205567R
#   FT-SA205568R
#   FT-SA205569R
#   FT-SA205570R
#   FT-SA205571R
#   FT-SA205572R
#   FT-SA205573R
#   FT-SA205574R
#   FT-SA205575R
#   FT-SA205576R
#   FT-SA205577R
#   FT-SA205578R
#   FT-SA205580R
#   FT-SA205581R
#   FT-SA205582R
#   FT-SA205583R
#   FT-SA205584R
#   FT-SA205585R
#   FT-SA205586R
#   FT-SA205587R
#   FT-SA205588R
#   FT-SA205589R
#   FT-SA205590R
#   FT-SA205591R
#   FT-SA205592R
#   FT-SA205593R
#   FT-SA205594R
#   FT-SA205595R
#   FT-SA205596R
#   FT-SA205598R
#   FT-SA205599R
#   FT-SA205600R
#   FT-SA205601R
#   FT-SA205602R
#   FT-SA205603R
#   FT-SA205604R
#   FT-SA205605R
#   FT-SA205606R
#   FT-SA205607R
#   FT-SA205608R
#   FT-SA205609R
#   FT-SA205610R
#   FT-SA205611R
#   FT-SA205612R
#   FT-SA205613R
#   FT-SA205614R
#   FT-SA205615R
#   FT-SA205616R
#   FT-SA205617R
#   FT-SA205618R
#   FT-SA205619R
#   FT-SA205620R
#   FT-SA205621R
#   FT-SA205622R
#   FT-SA205623R
#   FT-SA205624R
#   FT-SA205625R
#   FT-SA205626R
#   FT-SA205627R
#   FT-SA205628R
#   FT-SA205629R
#   FT-SA205630R
#   FT-SA205631R
#   FT-SA205632R
#   FT-SA205633R
#   FT-SA205634R
#   FT-SA205635R
#   FT-SA205636R
#   FT-SA205637R
#   FT-SA205638R
#   FT-SA205639R
#   FT-SA239552R
#   FT-SA239553R
#   FT-SA239554R
#   FT-SA239555R
#   FT-SA239556R
#   FT-SA239557R
#   FT-SA239558R
#   FT-SA239559R
#   FT-SA239560R
#   FT-SA239561R
#   FT-SA239562R
#   FT-SA239563R
#   FT-SA239564R
#   FT-SA239565R
#   FT-SA239566R
#   FT-SA239567R
#   FT-SA239568R
#   FT-SA239569R
#   FT-SA239570R
#   FT-SA239571R
#   FT-SA239572R
#   FT-SA239573R
#   FT-SA239574R
#   FT-SA239575R
#   FT-SA239576R
#   FT-SA239577R
#   FT-SA239578R
#   FT-SA239579R
#   FT-SA239580R
#   FT-SA239581R
#   FT-SA239582R
#   FT-SA239583R
#   FT-SA239584R
#   FT-SA239585R
#   FT-SA239586R
#   FT-SA239587R
#   FT-SA239588R
#   FT-SA239589R
#   FT-SA239590R
#   FT-SA239591R
    manifests_dpath: str,
    samples_per_manifest: int = 4
) -> list:
    """
    Generate manifest TSV files from sample IDs.

    Supported FASTQ naming conventions:
      - <sample>_R1.fastq.gz / <sample>_R2.fastq.gz
      - <sample>_1.fastq.gz  / <sample>_2.fastq.gz
    """
    import os
    import math

    os.makedirs(manifests_dpath, exist_ok=True)

    def resolve_fastq_pair(sample_id: str):
        """Return (fq1, fq2) paths for a sample, or raise if not found."""
        candidates = [
            (f"{sample_id}_R1.fastq.gz", f"{sample_id}_R2.fastq.gz"),
            (f"{sample_id}_1.fastq.gz",  f"{sample_id}_2.fastq.gz"),
        ]

        for fq1, fq2 in candidates:
            fq1_path = os.path.join(rawdata_path, fq1)
            fq2_path = os.path.join(rawdata_path, fq2)
            if os.path.isfile(fq1_path) and os.path.isfile(fq2_path):
                return fq1_path, fq2_path

        if not sample_id in IGNORE_SAMPLE_IDS:
            raise FileNotFoundError(
                f"No valid FASTQ pair found for sample '{sample_id}' "
                f"in {rawdata_path}"
            )
        else:
            return None

    # Calculate number of manifest files needed
    num_manifests = math.ceil(len(sample_ids) / samples_per_manifest)
    manifest_files = []

    for i in range(num_manifests):
        start_idx = i * samples_per_manifest
        end_idx = min(start_idx + samples_per_manifest, len(sample_ids))
        manifest_samples = sample_ids[start_idx:end_idx]

        lines = ["sample\tfq1\tfq2"]

        for sample_id in manifest_samples:
            res = resolve_fastq_pair(sample_id)
            if res is None:
                continue
            fq1_path, fq2_path = res
            lines.append(f"{sample_id}\t{fq1_path}\t{fq2_path}")

        manifest_filename = f"manifest_{i}.tsv"
        manifest_filepath = os.path.join(manifests_dpath, manifest_filename)

        with open(manifest_filepath, "w") as f:
            f.write("\n".join(lines) + "\n")

        manifest_files.append(manifest_filepath)
        print(f"Generated {manifest_filename} with {len(manifest_samples)} samples")

    return manifest_files

# %%
# Generate manifest files
manifest_files = generate_manifest_files(sample_ids, rawdata_path, manifests_dpath)

print(f"\nGenerated {len(manifest_files)} manifest files:")
for manifest_file in manifest_files:
    print(f"  {manifest_file}")

# Display content of first manifest file as example
if manifest_files:
    print(f"\nContent of {os.path.basename(manifest_files[0])}:")
    with open(manifest_files[0], 'r') as f:
        print(f.read())
# Out:
# Generated manifest_0.tsv with 4 samples
# Generated manifest_1.tsv with 4 samples
# Generated manifest_2.tsv with 4 samples
# Generated manifest_3.tsv with 4 samples
# Generated manifest_4.tsv with 4 samples
# Generated manifest_5.tsv with 4 samples
# Generated manifest_6.tsv with 4 samples
# Generated manifest_7.tsv with 4 samples
# Generated manifest_8.tsv with 4 samples
# Generated manifest_9.tsv with 4 samples
# Generated manifest_10.tsv with 4 samples
# Generated manifest_11.tsv with 4 samples
# Generated manifest_12.tsv with 4 samples
# Generated manifest_13.tsv with 4 samples
# Generated manifest_14.tsv with 4 samples
# Generated manifest_15.tsv with 4 samples
# Generated manifest_16.tsv with 4 samples
# Generated manifest_17.tsv with 4 samples
# Generated manifest_18.tsv with 4 samples
# Generated manifest_19.tsv with 4 samples
# Generated manifest_20.tsv with 4 samples
# Generated manifest_21.tsv with 4 samples
# Generated manifest_22.tsv with 4 samples
# Generated manifest_414.tsv with 4 samples
# Generated manifest_415.tsv with 4 samples
# Generated manifest_416.tsv with 4 samples
# Generated manifest_417.tsv with 4 samples
# Generated manifest_418.tsv with 4 samples
# Generated manifest_419.tsv with 4 samples
# Generated manifest_420.tsv with 4 samples
# Generated manifest_421.tsv with 4 samples
# Generated manifest_422.tsv with 4 samples
# Generated manifest_423.tsv with 4 samples
# Generated manifest_424.tsv with 4 samples
# Generated manifest_425.tsv with 4 samples
# Generated manifest_426.tsv with 4 samples
# Generated manifest_427.tsv with 1 samples
#
# Generated 428 manifest files:
#   manifests/manifest_0.tsv
#   manifests/manifest_1.tsv
#   manifests/manifest_2.tsv
#   manifests/manifest_3.tsv
#   manifests/manifest_4.tsv
#   manifests/manifest_5.tsv
#   manifests/manifest_6.tsv
#   manifests/manifest_7.tsv
#   manifests/manifest_8.tsv
#   manifests/manifest_9.tsv
#   manifests/manifest_10.tsv
#   manifests/manifest_11.tsv
#   manifests/manifest_12.tsv
#   manifests/manifest_13.tsv
#   manifests/manifest_14.tsv
#   manifests/manifest_15.tsv
#   manifests/manifest_16.tsv
#   manifests/manifest_17.tsv
#   manifests/manifest_18.tsv
#   manifests/manifest_19.tsv
#   manifests/manifest_20.tsv
#   manifests/manifest_21.tsv
#   manifests/manifest_22.tsv
#   manifests/manifest_23.tsv
#   manifests/manifest_24.tsv
#   manifests/manifest_25.tsv
#   manifests/manifest_26.tsv
#   manifests/manifest_27.tsv
#   manifests/manifest_28.tsv
#   manifests/manifest_29.tsv
#   manifests/manifest_30.tsv
#   manifests/manifest_31.tsv
#   manifests/manifest_32.tsv
#   manifests/manifest_33.tsv
#   manifests/manifest_34.tsv
#   manifests/manifest_35.tsv
#   manifests/manifest_36.tsv
#   manifests/manifest_37.tsv
#   manifests/manifest_38.tsv
#   manifests/manifest_39.tsv
#   manifests/manifest_40.tsv
#   manifests/manifest_41.tsv
#   manifests/manifest_42.tsv
#   manifests/manifest_43.tsv
#   manifests/manifest_44.tsv
#   manifests/manifest_45.tsv
#   manifests/manifest_46.tsv
#   manifests/manifest_47.tsv
#   manifests/manifest_48.tsv
#   manifests/manifest_49.tsv
#   manifests/manifest_50.tsv
#   manifests/manifest_51.tsv
#   manifests/manifest_52.tsv
#   manifests/manifest_53.tsv
#   manifests/manifest_54.tsv
#   manifests/manifest_55.tsv
#   manifests/manifest_56.tsv
#   manifests/manifest_57.tsv
#   manifests/manifest_58.tsv
#   manifests/manifest_59.tsv
#   manifests/manifest_60.tsv
#   manifests/manifest_61.tsv
#   manifests/manifest_62.tsv
#   manifests/manifest_63.tsv
#   manifests/manifest_64.tsv
#   manifests/manifest_65.tsv
#   manifests/manifest_66.tsv
#   manifests/manifest_67.tsv
#   manifests/manifest_68.tsv
#   manifests/manifest_69.tsv
#   manifests/manifest_70.tsv
#   manifests/manifest_71.tsv
#   manifests/manifest_72.tsv
#   manifests/manifest_73.tsv
#   manifests/manifest_74.tsv
#   manifests/manifest_75.tsv
#   manifests/manifest_76.tsv
#   manifests/manifest_77.tsv
#   manifests/manifest_78.tsv
#   manifests/manifest_79.tsv
#   manifests/manifest_80.tsv
#   manifests/manifest_81.tsv
#   manifests/manifest_82.tsv
#   manifests/manifest_83.tsv
#   manifests/manifest_84.tsv
#   manifests/manifest_85.tsv
#   manifests/manifest_86.tsv
#   manifests/manifest_87.tsv
#   manifests/manifest_88.tsv
#   manifests/manifest_89.tsv
#   manifests/manifest_90.tsv
#   manifests/manifest_91.tsv
#   manifests/manifest_92.tsv
#   manifests/manifest_93.tsv
#   manifests/manifest_94.tsv
#   manifests/manifest_95.tsv
#   manifests/manifest_96.tsv
#   manifests/manifest_97.tsv
#   manifests/manifest_98.tsv
#   manifests/manifest_99.tsv
#   manifests/manifest_100.tsv
#   manifests/manifest_101.tsv
#   manifests/manifest_102.tsv
#   manifests/manifest_103.tsv
#   manifests/manifest_104.tsv
#   manifests/manifest_105.tsv
#   manifests/manifest_106.tsv
#   manifests/manifest_107.tsv
#   manifests/manifest_108.tsv
#   manifests/manifest_109.tsv
#   manifests/manifest_110.tsv
#   manifests/manifest_111.tsv
#   manifests/manifest_112.tsv
#   manifests/manifest_113.tsv
#   manifests/manifest_114.tsv
#   manifests/manifest_115.tsv
#   manifests/manifest_116.tsv
#   manifests/manifest_117.tsv
#   manifests/manifest_118.tsv
#   manifests/manifest_119.tsv
#   manifests/manifest_120.tsv
#   manifests/manifest_121.tsv
#   manifests/manifest_122.tsv
#   manifests/manifest_123.tsv
#   manifests/manifest_124.tsv
#   manifests/manifest_125.tsv
#   manifests/manifest_126.tsv
#   manifests/manifest_127.tsv
#   manifests/manifest_128.tsv
#   manifests/manifest_129.tsv
#   manifests/manifest_130.tsv
#   manifests/manifest_131.tsv
#   manifests/manifest_132.tsv
#   manifests/manifest_133.tsv
#   manifests/manifest_134.tsv
#   manifests/manifest_135.tsv
#   manifests/manifest_136.tsv
#   manifests/manifest_137.tsv
#   manifests/manifest_138.tsv
#   manifests/manifest_139.tsv
#   manifests/manifest_140.tsv
#   manifests/manifest_141.tsv
#   manifests/manifest_142.tsv
#   manifests/manifest_143.tsv
#   manifests/manifest_144.tsv
#   manifests/manifest_145.tsv
#   manifests/manifest_146.tsv
#   manifests/manifest_147.tsv
#   manifests/manifest_148.tsv
#   manifests/manifest_149.tsv
#   manifests/manifest_150.tsv
#   manifests/manifest_151.tsv
#   manifests/manifest_152.tsv
#   manifests/manifest_153.tsv
#   manifests/manifest_154.tsv
#   manifests/manifest_155.tsv
#   manifests/manifest_156.tsv
#   manifests/manifest_157.tsv
#   manifests/manifest_158.tsv
#   manifests/manifest_159.tsv
#   manifests/manifest_160.tsv
#   manifests/manifest_161.tsv
#   manifests/manifest_162.tsv
#   manifests/manifest_163.tsv
#   manifests/manifest_164.tsv
#   manifests/manifest_165.tsv
#   manifests/manifest_166.tsv
#   manifests/manifest_167.tsv
#   manifests/manifest_168.tsv
#   manifests/manifest_169.tsv
#   manifests/manifest_170.tsv
#   manifests/manifest_171.tsv
#   manifests/manifest_172.tsv
#   manifests/manifest_173.tsv
#   manifests/manifest_174.tsv
#   manifests/manifest_175.tsv
#   manifests/manifest_176.tsv
#   manifests/manifest_177.tsv
#   manifests/manifest_178.tsv
#   manifests/manifest_179.tsv
#   manifests/manifest_180.tsv
#   manifests/manifest_181.tsv
#   manifests/manifest_182.tsv
#   manifests/manifest_183.tsv
#   manifests/manifest_184.tsv
#   manifests/manifest_185.tsv
#   manifests/manifest_186.tsv
#   manifests/manifest_187.tsv
#   manifests/manifest_188.tsv
#   manifests/manifest_189.tsv
#   manifests/manifest_190.tsv
#   manifests/manifest_191.tsv
#   manifests/manifest_192.tsv
#   manifests/manifest_193.tsv
#   manifests/manifest_194.tsv
#   manifests/manifest_195.tsv
#   manifests/manifest_196.tsv
#   manifests/manifest_197.tsv
#   manifests/manifest_198.tsv
#   manifests/manifest_199.tsv
#   manifests/manifest_200.tsv
#   manifests/manifest_201.tsv
#   manifests/manifest_202.tsv
#   manifests/manifest_203.tsv
#   manifests/manifest_204.tsv
#   manifests/manifest_205.tsv
#   manifests/manifest_206.tsv
#   manifests/manifest_207.tsv
#   manifests/manifest_208.tsv
#   manifests/manifest_209.tsv
#   manifests/manifest_210.tsv
#   manifests/manifest_211.tsv
#   manifests/manifest_212.tsv
#   manifests/manifest_213.tsv
#   manifests/manifest_214.tsv
#   manifests/manifest_215.tsv
#   manifests/manifest_216.tsv
#   manifests/manifest_217.tsv
#   manifests/manifest_218.tsv
#   manifests/manifest_219.tsv
#   manifests/manifest_220.tsv
#   manifests/manifest_221.tsv
#   manifests/manifest_222.tsv
#   manifests/manifest_223.tsv
#   manifests/manifest_224.tsv
#   manifests/manifest_225.tsv
#   manifests/manifest_226.tsv
#   manifests/manifest_227.tsv
#   manifests/manifest_228.tsv
#   manifests/manifest_229.tsv
#   manifests/manifest_230.tsv
#   manifests/manifest_231.tsv
#   manifests/manifest_232.tsv
#   manifests/manifest_233.tsv
#   manifests/manifest_234.tsv
#   manifests/manifest_235.tsv
#   manifests/manifest_236.tsv
#   manifests/manifest_237.tsv
#   manifests/manifest_238.tsv
#   manifests/manifest_239.tsv
#   manifests/manifest_240.tsv
#   manifests/manifest_241.tsv
#   manifests/manifest_242.tsv
#   manifests/manifest_243.tsv
#   manifests/manifest_244.tsv
#   manifests/manifest_245.tsv
#   manifests/manifest_246.tsv
#   manifests/manifest_247.tsv
#   manifests/manifest_248.tsv
#   manifests/manifest_249.tsv
#   manifests/manifest_250.tsv
#   manifests/manifest_251.tsv
#   manifests/manifest_252.tsv
#   manifests/manifest_253.tsv
#   manifests/manifest_254.tsv
#   manifests/manifest_255.tsv
#   manifests/manifest_256.tsv
#   manifests/manifest_257.tsv
#   manifests/manifest_258.tsv
#   manifests/manifest_259.tsv
#   manifests/manifest_260.tsv
#   manifests/manifest_261.tsv
#   manifests/manifest_262.tsv
#   manifests/manifest_263.tsv
#   manifests/manifest_264.tsv
#   manifests/manifest_265.tsv
#   manifests/manifest_266.tsv
#   manifests/manifest_267.tsv
#   manifests/manifest_268.tsv
#   manifests/manifest_269.tsv
#   manifests/manifest_270.tsv
#   manifests/manifest_271.tsv
#   manifests/manifest_272.tsv
#   manifests/manifest_273.tsv
#   manifests/manifest_274.tsv
#   manifests/manifest_275.tsv
#   manifests/manifest_276.tsv
#   manifests/manifest_277.tsv
#   manifests/manifest_278.tsv
#   manifests/manifest_279.tsv
#   manifests/manifest_280.tsv
#   manifests/manifest_281.tsv
#   manifests/manifest_282.tsv
#   manifests/manifest_283.tsv
#   manifests/manifest_284.tsv
#   manifests/manifest_285.tsv
#   manifests/manifest_286.tsv
#   manifests/manifest_287.tsv
#   manifests/manifest_288.tsv
#   manifests/manifest_289.tsv
#   manifests/manifest_290.tsv
#   manifests/manifest_291.tsv
#   manifests/manifest_292.tsv
#   manifests/manifest_293.tsv
#   manifests/manifest_294.tsv
#   manifests/manifest_295.tsv
#   manifests/manifest_296.tsv
#   manifests/manifest_297.tsv
#   manifests/manifest_298.tsv
#   manifests/manifest_299.tsv
#   manifests/manifest_300.tsv
#   manifests/manifest_301.tsv
#   manifests/manifest_302.tsv
#   manifests/manifest_303.tsv
#   manifests/manifest_304.tsv
#   manifests/manifest_305.tsv
#   manifests/manifest_306.tsv
#   manifests/manifest_307.tsv
#   manifests/manifest_308.tsv
#   manifests/manifest_309.tsv
#   manifests/manifest_310.tsv
#   manifests/manifest_311.tsv
#   manifests/manifest_312.tsv
#   manifests/manifest_313.tsv
#   manifests/manifest_314.tsv
#   manifests/manifest_315.tsv
#   manifests/manifest_316.tsv
#   manifests/manifest_317.tsv
#   manifests/manifest_318.tsv
#   manifests/manifest_319.tsv
#   manifests/manifest_320.tsv
#   manifests/manifest_321.tsv
#   manifests/manifest_322.tsv
#   manifests/manifest_323.tsv
#   manifests/manifest_324.tsv
#   manifests/manifest_325.tsv
#   manifests/manifest_326.tsv
#   manifests/manifest_327.tsv
#   manifests/manifest_328.tsv
#   manifests/manifest_329.tsv
#   manifests/manifest_330.tsv
#   manifests/manifest_331.tsv
#   manifests/manifest_332.tsv
#   manifests/manifest_333.tsv
#   manifests/manifest_334.tsv
#   manifests/manifest_335.tsv
#   manifests/manifest_336.tsv
#   manifests/manifest_337.tsv
#   manifests/manifest_338.tsv
#   manifests/manifest_339.tsv
#   manifests/manifest_340.tsv
#   manifests/manifest_341.tsv
#   manifests/manifest_342.tsv
#   manifests/manifest_343.tsv
#   manifests/manifest_344.tsv
#   manifests/manifest_345.tsv
#   manifests/manifest_346.tsv
#   manifests/manifest_347.tsv
#   manifests/manifest_348.tsv
#   manifests/manifest_349.tsv
#   manifests/manifest_350.tsv
#   manifests/manifest_351.tsv
#   manifests/manifest_352.tsv
#   manifests/manifest_353.tsv
#   manifests/manifest_354.tsv
#   manifests/manifest_355.tsv
#   manifests/manifest_356.tsv
#   manifests/manifest_357.tsv
#   manifests/manifest_358.tsv
#   manifests/manifest_359.tsv
#   manifests/manifest_360.tsv
#   manifests/manifest_361.tsv
#   manifests/manifest_362.tsv
#   manifests/manifest_363.tsv
#   manifests/manifest_364.tsv
#   manifests/manifest_365.tsv
#   manifests/manifest_366.tsv
#   manifests/manifest_367.tsv
#   manifests/manifest_368.tsv
#   manifests/manifest_369.tsv
#   manifests/manifest_370.tsv
#   manifests/manifest_371.tsv
#   manifests/manifest_372.tsv
#   manifests/manifest_373.tsv
#   manifests/manifest_374.tsv
#   manifests/manifest_375.tsv
#   manifests/manifest_376.tsv
#   manifests/manifest_377.tsv
#   manifests/manifest_378.tsv
#   manifests/manifest_379.tsv
#   manifests/manifest_380.tsv
#   manifests/manifest_381.tsv
#   manifests/manifest_382.tsv
#   manifests/manifest_383.tsv
#   manifests/manifest_384.tsv
#   manifests/manifest_385.tsv
#   manifests/manifest_386.tsv
#   manifests/manifest_387.tsv
#   manifests/manifest_388.tsv
#   manifests/manifest_389.tsv
#   manifests/manifest_390.tsv
#   manifests/manifest_391.tsv
#   manifests/manifest_392.tsv
#   manifests/manifest_393.tsv
#   manifests/manifest_394.tsv
#   manifests/manifest_395.tsv
#   manifests/manifest_396.tsv
#   manifests/manifest_397.tsv
#   manifests/manifest_398.tsv
#   manifests/manifest_399.tsv
#   manifests/manifest_400.tsv
#   manifests/manifest_401.tsv
#   manifests/manifest_402.tsv
#   manifests/manifest_403.tsv
#   manifests/manifest_404.tsv
#   manifests/manifest_405.tsv
#   manifests/manifest_406.tsv
#   manifests/manifest_407.tsv
#   manifests/manifest_408.tsv
#   manifests/manifest_409.tsv
#   manifests/manifest_410.tsv
#   manifests/manifest_411.tsv
#   manifests/manifest_412.tsv
#   manifests/manifest_413.tsv
#   manifests/manifest_414.tsv
#   manifests/manifest_415.tsv
#   manifests/manifest_416.tsv
#   manifests/manifest_417.tsv
#   manifests/manifest_418.tsv
#   manifests/manifest_419.tsv
#   manifests/manifest_420.tsv
#   manifests/manifest_421.tsv
#   manifests/manifest_422.tsv
#   manifests/manifest_423.tsv
#   manifests/manifest_424.tsv
#   manifests/manifest_425.tsv
#   manifests/manifest_426.tsv
#   manifests/manifest_427.tsv
#
# Content of manifest_0.tsv:
# sample	fq1	fq2
# AZSFJ00239-RNA	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00239-RNA_R1.fastq.gz	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00239-RNA_R2.fastq.gz
# AZSFJ00240-RNA	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00240-RNA_R1.fastq.gz	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00240-RNA_R2.fastq.gz
# AZSFJ00241-RNA	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00241-RNA_R1.fastq.gz	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00241-RNA_R2.fastq.gz
# AZSFJ00242-RNA	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00242-RNA_R1.fastq.gz	/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq/AZSFJ00242-RNA_R2.fastq.gz

# %%
bowtie_job_template = """#!/bin/bash
#SBATCH --time=96:00:00
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=[NO_CORES]
#SBATCH --mem=256G
#SBATCH --job-name=immuno_retrovirus
#SBATCH --account=PDE0005
#SBATCH --error=immuno_retrovirus-%j.err
#SBATCH --output=immuno_retrovirus-%j.out

set -euo pipefail
set -x

cd "${SLURM_SUBMIT_DIR}"

module load miniconda3/24.1.2-py310
source "$(conda info --base)/etc/profile.d/conda.sh"
conda activate immuno_telescope

export PROJECT_PATH="/fs/scratch/PDE0005/projects/telescope_TCC00573"
export SAMPLES_PATH="/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq"

rm -rf "${PROJECT_PATH}/tmp_[MANIFEST_ID]"
mkdir -p "${PROJECT_PATH}/tmp_[MANIFEST_ID]"

# copy code + manifests into node-local space
cp -R \
  "/fs/scratch/PDE0005/telescope_lungsamples/code/lib" \
  "/fs/scratch/PDE0005/telescope_lungsamples/code/run.py" \
  "${PROJECT_PATH}/manifests/manifest_[MANIFEST_ID].tsv" \
  "${TMPDIR}/"

cp -R \
  "/fs/scratch/PDE0005/telescope_lungsamples/data/Indexes" \
  "/fs/scratch/PDE0005/telescope_lungsamples/data/REF" \
  "${TMPDIR}/"

cd "${TMPDIR}"
mkdir -p output

python run.py \
  --manifest manifest_[MANIFEST_ID].tsv \
  --gtf REF/gencode.v39.annotation.gtf \
  --genome REF/GRCh38.p13.genome.fa \
  --transcript REF/gencode.v39.transcripts.fa \
  --herv_gtf REF/HG38_HERV_LINE_all_families_telescope_ann.gtf \
  --bowtiew2_idx Indexes/gencode.v39_bowtie2/human \
  --workflows BOWTIE \
  --out_dir output \
  --samples_dir "${SAMPLES_PATH}" \
  --n_cores "${SLURM_CPUS_PER_TASK}" \
  --trimgalore_n_cores 6 \
  --telescope_n_cores 1 \
  --seed 123456 \
  --scratch_dir "${PROJECT_PATH}/tmp_[MANIFEST_ID]" \
  --fastq_mode \
  --sample_check_n_cores 6

LOGS="${TMPDIR}/output/BOWTIE/logs.tsv"
if [ -f "${LOGS}" ]; then
  cp "${LOGS}" "${PROJECT_PATH}/output/BOWTIE/logs_[MANIFEST_ID].tsv"
fi

BOWTIE_DIR="${TMPDIR}/output/BOWTIE"
if [ -d "${BOWTIE_DIR}" ]; then
  rsync -a "${BOWTIE_DIR}/" "${PROJECT_PATH}/output/BOWTIE/"
fi

"""

# %%
telescope_job_template: str = """#!/bin/bash
#SBATCH --time=144:00:00
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=[NO_CORES]
#SBATCH --mem=256GB
#SBATCH --job-name=immuno_retrovirus
#SBATCH --account=PDE0005
#SBATCH -e immuno_retrovirus-%j.err
#SBATCH -o immuno_retrovirus-%j.out

set echo

# slurm starts job in working DIR
cd $SLURM_SUBMIT_DIR

# set up software environment
module load intel/2021.10.0
module load miniconda3/24.1.2-py310

source activate immuno_telescope

export CMPLR_ROOT="/apps/spack/0.21/ascend/linux-rhel9-zen2/intel-oneapi-compilers/gcc/11.4.1/2023.2.3-nkzjnam/compiler/2023.2.3"
export INTEL64="$CMPLR_ROOT/linux/compiler/lib/intel64_lin"
export LD_LIBRARY_PATH="$INTEL64:$CMPLR_ROOT/linux/lib:$CMPLR_ROOT/linux/lib/x64:$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# Optional (only if you still see unresolved Intel symbols):
export LD_PRELOAD="$INTEL64/libimf.so:$INTEL64/libsvml.so:$INTEL64/libirc.so"

# 4) (Optional) sanity check that the Telescope C extension loads
python - <<'PY'
import ctypes, glob, os, sys
pats = glob.glob(os.path.expanduser("~/.conda/envs/immuno_telescope/lib/python3.6/site-packages/telescope/utils/calignment*.so"))
if not pats:
    sys.exit("Telescope extension not found")
ctypes.CDLL(pats[0])
print("Loaded Telescope extension OK:", pats[0])
PY

export PROJECT_PATH="/fs/scratch/PDE0005/projects/telescope_TCC00573"
export SAMPLES_PATH="/fs/ess/PDE0054/TCC00573-ROLF/RNAseq/fastq"

# copy data to compute node local space $TMPDIR
cp -R \
    /fs/scratch/PDE0005/telescope_lungsamples/code/lib \
    /fs/scratch/PDE0005/telescope_lungsamples/code/run.py \
    $TMPDIR/
    
cp -R \
    /fs/scratch/PDE0005/telescope_lungsamples/data/Indexes \
    /fs/scratch/PDE0005/telescope_lungsamples/data/REF \
    $TMPDIR/

cd $TMPDIR

mkdir output

# $PFSDIR: /fs/scratch/PAS0438/osu9787/18091549.owens

    
python run.py \
    --gtf REF/gencode.v39.annotation.gtf \
    --genome REF/GRCh38.p13.genome.fa \
    --transcript REF/gencode.v39.transcripts.fa \
    --herv_gtf REF/HG38_HERV_LINE_all_families_telescope_ann.gtf \
    --bowtiew2_idx Indexes/gencode.v39_bowtie2/human \
    --workflows TELESCOPE \
    --out_dir output \
    --scratch_dir $PROJECT_PATH/tmp_[MANIFEST_ID] \
    --n_cores [NO_CORES] \
    --trimgalore_n_cores 6 \
    --telescope_n_cores 1 \
    --seed 123456 \
    --fastq_mode


LOGS="$TMPDIR/output/TELESCOPE/logs.tsv"
if [ -f "$LOGS" ]; then
  cp $LOGS $PROJECT_PATH/output/TELESCOPE/logs_[MANIFEST_ID].tsv
fi

BOWTIE_DIR="$TMPDIR/output/TELESCOPE"
if [ -d "$BOWTIE_DIR" ]; then
  cp -R $BOWTIE_DIR/* $PROJECT_PATH/output/TELESCOPE/
fi
"""

# %%
num_manifests: int = len(manifest_files)
for i in range(num_manifests):
    j_tmp: str = bowtie_job_template
        
    with open(Path(jobs_s1_dpath, f"job_{i}.sh"), "w") as f:
        f.write(j_tmp.replace("[NO_CORES]", "24").replace("[MANIFEST_ID]", str(i)))
    
    print(f"sbatch {jobs_s1_dpath}/job_{i}.sh --gres=pfsdir:ess")
# Out:
# sbatch jobs_step1/job_0.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_1.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_2.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_3.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_4.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_5.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_6.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_7.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_8.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_9.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_10.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_11.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_12.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_13.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_14.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_15.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_16.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_17.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_18.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_19.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_20.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_21.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_22.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_23.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_24.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_25.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_26.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_27.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_28.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_29.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_30.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_31.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_32.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_33.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_34.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_35.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_36.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_37.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_38.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_39.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_40.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_41.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_42.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_43.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_44.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_45.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_46.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_47.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_48.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_49.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_50.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_51.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_52.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_53.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_54.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_55.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_56.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_57.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_58.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_59.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_60.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_61.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_62.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_63.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_64.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_65.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_66.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_67.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_68.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_69.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_70.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_71.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_72.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_73.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_74.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_75.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_76.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_77.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_78.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_79.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_80.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_81.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_82.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_83.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_84.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_85.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_86.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_87.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_88.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_89.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_90.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_91.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_92.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_93.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_94.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_95.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_96.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_97.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_98.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_99.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_100.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_101.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_102.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_103.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_104.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_105.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_106.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_107.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_108.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_109.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_110.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_111.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_112.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_113.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_114.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_115.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_116.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_117.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_118.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_119.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_120.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_121.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_122.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_123.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_124.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_125.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_126.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_127.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_128.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_129.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_130.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_131.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_132.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_133.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_134.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_135.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_136.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_137.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_138.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_139.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_140.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_141.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_142.sh --gres=pfsdir:ess
# sbatch jobs_step1/job_143.sh --gres=pfsdir:ess
# sbatch jobs_step1/job